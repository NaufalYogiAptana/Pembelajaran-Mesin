# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Pembelajaran Mesin/PRAKTIKUM 2/data.csv")
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1 = pd.read_csv("/content/drive/MyDrive/Pembelajaran Mesin/PRAKTIKUM 2/data.csv",
skiprows=1, names=["durasi","nadi","maxnadi","kalori"])
print (data1.loc[:,["durasi"]])
# Out:
#      durasi
# 0        60
# 1        60
# 2        60
# 3        45
# 4        45
# ..      ...
# 164      60
# 165      60
# 166      60
# 167      75
# 168      75
#
# [169 rows x 1 columns]

# %%
data1 = pd.read_csv("/content/drive/MyDrive/Pembelajaran Mesin/PRAKTIKUM 2/data.csv",
skiprows=1, names=["durasi","nadi","maxnadi","kalori"])
print (data1.loc[:,["durasi","kalori"]])
# Out:
#      durasi  kalori
# 0        60   409.1
# 1        60   479.0
# 2        60   340.0
# 3        45   282.4
# 4        45   406.0
# ..      ...     ...
# 164      60   290.8
# 165      60   300.0
# 166      60   310.2
# 167      75   320.4
# 168      75   330.4
#
# [169 rows x 2 columns]

# %%
data1.loc[0:10,:]
# Out:
#     durasi  nadi  maxnadi  kalori
# 0       60   110      130   409.1
# 1       60   117      145   479.0
# 2       60   103      135   340.0
# 3       45   109      175   282.4
# 4       45   117      148   406.0
# 5       60   102      127   300.0
# 6       60   110      136   374.0
# 7       45   104      134   253.3
# 8       30   109      133   195.1
# 9       60    98      124   269.0
# 10      60   103      147   329.3

# %%
data1.loc[0:10:,["durasi","kalori"]]
# Out:
#     durasi  kalori
# 0       60   409.1
# 1       60   479.0
# 2       60   340.0
# 3       45   282.4
# 4       45   406.0
# 5       60   300.0
# 6       60   374.0
# 7       45   253.3
# 8       30   195.1
# 9       60   269.0
# 10      60   329.3

# %%
data1.iloc[:,[2]]
# Out:
#      maxnadi
# 0        130
# 1        145
# 2        135
# 3        175
# 4        148
# ..       ...
# 164      140
# 165      145
# 166      145
# 167      150
# 168      150
#
# [169 rows x 1 columns]

# %%
data1.iloc[:,[1,2]]
# Out:
#      nadi  maxnadi
# 0     110      130
# 1     117      145
# 2     103      135
# 3     109      175
# 4     117      148
# ..    ...      ...
# 164   105      140
# 165   110      145
# 166   115      145
# 167   120      150
# 168   125      150
#
# [169 rows x 2 columns]

# %%
data1.iloc[:,:2]
# Out:
#      durasi  nadi
# 0        60   110
# 1        60   117
# 2        60   103
# 3        45   109
# 4        45   117
# ..      ...   ...
# 164      60   105
# 165      60   110
# 166      60   115
# 167      75   120
# 168      75   125
#
# [169 rows x 2 columns]

# %%
data1.iloc[:,1:3]
# Out:
#      nadi  maxnadi
# 0     110      130
# 1     117      145
# 2     103      135
# 3     109      175
# 4     117      148
# ..    ...      ...
# 164   105      140
# 165   110      145
# 166   115      145
# 167   120      150
# 168   125      150
#
# [169 rows x 2 columns]

# %%
from matplotlib import pyplot
data1.hist()
pyplot.show()

# %%
data1.plot(kind='density', subplots=True, layout= (2,2), sharex= False)
pyplot.show()

# %%
data1.plot(kind='density', subplots=True, layout= (2,2), sharex= False)
pyplot.show()

# %%
import numpy
correlations = data1.corr()
#plotcorrelationmatrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,4,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(data1.columns)
ax.set_yticklabels(data1.columns)
pyplot.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data1)
pyplot.show()
